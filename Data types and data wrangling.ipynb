# %%
import pandas as pd
url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'
fuel_data = pd.read_csv(url, error_bad_lines=False)
fuel_data.describe(include='all')

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Dell\Desktop\Excel.lnk')
print(df)
# Out:
# Empty DataFrame
# Columns: [L, Unnamed: 1, Unnamed: 2, Unnamed: 3]
# Index: []

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Dell'

# %%
fuel_data = pd.read_csv(r'C:\Users\Dell\Desktop\fuel_ferc1.csv')
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# 2               24.130                      39.72
# 3               23.950                      47.21
# 4                1.000                       2.77
#
#    fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# 0                         18.53                1.121
# 1                         18.53                1.120
# 2                         38.12                1.650
# 3                         45.99                1.970
# 4                          2.77                2.570

# %%
fuel_data = pd.read_csv(r'C:\Users\Dell\Desktop\fuel_ferc1.csv', error_bad_lines=False)
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.duplicated().any()
# Out:
# False

# %%
fuel_data.groupby('fuel_unit').first()
# Out:
#                          record_id  utility_id_ferc1  report_year  \
# fuel_unit
# bbl          f1_fuel_1994_12_6_0_2                 6         1994
# gal        f1_fuel_2000_12_20_0_10                20         2000
# gramsU       f1_fuel_1994_12_9_0_8                 9         1994
# kgU          f1_fuel_1994_12_2_1_1                 2         1994
# mcf         f1_fuel_1994_12_2_0_10                 2         1994
# mmbtu       f1_fuel_1994_12_46_1_7                46         1994
# mwdth      f1_fuel_1994_12_17_2_14                17         1994
# mwhth       f1_fuel_1994_12_63_0_2                63         1994
# ton          f1_fuel_1994_12_1_0_7                 1         1994
#
#             plant_name_ferc1 fuel_type_code_pudl  fuel_qty_burned  \
# fuel_unit
# bbl             clinch river                 oil           6510.0
# gal                  hallock                 oil          56925.0
# gramsU            pch bt 2&3             nuclear         204246.0
# kgU         joseph m. farley             nuclear           2260.0
# mcf                chickasaw                 gas          40533.0
# mmbtu               perry #1             nuclear        6619313.0
# mwdth         h. b. robinson             nuclear         632744.0
# mwhth      river bend unit 1             nuclear       10748582.0
# ton                 rockport                coal        5377489.0
#
#            fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_unit
# bbl                   5.875338                     32.130
# gal                   5.527200                      1.095
# gramsU                0.000065                     44.000
# kgU                   0.064094                     28.770
# mcf                   1.000000                      2.770
# mmbtu                 0.110455                      1.170
# mwdth                 3.413000                     38.960
# mwhth                 3.412600                      3.801
# ton                  16.590000                     18.590
#
#            fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# fuel_unit
# bbl                              23.444                5.469
# gal                               1.096                8.324
# gramsU                            0.000                0.679
# kgU                               0.000                0.450
# mcf                               2.770                2.570
# mmbtu                             0.000                1.170
# mwdth                             0.000                0.476
# mwhth                             0.000                1.114
# ton                              18.530                1.121

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))
pd.merge(fuel_df1, fuel_df2, how="inner")
pd.merge(fuel_df1, fuel_df2, how="outer")
pd.merge(fuel_df1, fuel_df2, how="left")
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# ...                         ...               ...          ...
# 18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999    f1_fuel_2009_12_79_0_1                79         2009
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# 1      rockport total plant                coal       ton       10486945.0
# 2                    gorgas                coal       ton        2978683.0
# 3                     barry                coal       ton        3739484.0
# 4                 chickasaw                 gas       mcf          40533.0
# ...                     ...                 ...       ...              ...
# 18995             lake road                 gas       mcf         340857.0
# 18996             lake road                 oil       mcf            771.0
# 18997           iatan (18%)                coal       ton         414142.0
# 18998           iatan (18%)                 oil       bbl           5761.0
# 18999              montrose                coal       ton        2050919.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0                16.590000                     18.590
# 1                16.592000                     18.580
# 2                24.130000                     39.720
# 3                23.950000                     47.210
# 4                 1.000000                      2.770
# ...                    ...                        ...
# 18995             1.000000                      4.711
# 18996             5.801544                     84.899
# 18997            16.718000                     18.509
# 18998             5.537910                     83.636
# 18999            17.160000                     29.629
#
#        fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# 0                            18.530                1.121
# 1                            18.530                1.120
# 2                            38.120                1.650
# 3                            45.990                1.970
# 4                             2.770                2.570
# ...                             ...                  ...
# 18995                         4.711                4.711
# 18996                        84.899               14.634
# 18997                        17.570                1.107
# 18998                        72.280               15.102
# 18999                        28.330                1.727
#
# [19000 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
            'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')

#Because of the extreme range of the values for the fuel unit, we can plot the barchart by taking the logarithm of the y-axis as follows:


g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
            'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')

#Because of the extreme range of the values for the fuel unit, we can plot the barchart by taking the logarithm of the y-axis as follows:


g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-15c6ce307ae9> in <module>
#       5 fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
#       6             'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
# ----> 7 sns.barplot(data=fuel_unit, x='unit', y='count')
#       8 plt.xlabel('Fuel Unit')
#       9
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
            'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')




g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-fb359b20e623> in <module>
#       5 fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
#       6             'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
# ----> 7 sns.barplot(data=fuel_unit, x='unit', y='count')
#       8 plt.xlabel('Fuel Unit')
#       9
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(7, 4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL','GAL','GRAMSU','KGU','MCF','MMBTU','MWDTH','TON'],
                         'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')
g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-4d202fdb26ad> in <module>
#       3 plt.figure(figsize=(7, 4))
#       4 plt.xticks(rotation=90)
# ----> 5 fuel_unit = pd.DataFrame({'unit':['BBL','GAL','GRAMSU','KGU','MCF','MMBTU','MWDTH','TON'],
#       6                          'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
#       7 sns.barplot(data=fuel_unit, x='unit', y='count')
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length
